# %%
#TASK 2->1(a)

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print(nod.element)
                nod=nod.ne
                
            
a=[20,30,40,50,60,70]
b=DoublyList(a)
b.showList()
# Out:
# 20
# 30
# 40
# 50
# 60
# 70

# %%
#TASK 2->2

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print(nod.element)
                nod=nod.ne
            
a=[20,30,40,50,60,70]
b=DoublyList(a)
b.showList()
# Out:
# 20
# 30
# 40
# 50
# 60
# 70

# %%
#TASK 2->3

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print(nod.element)
                nod=nod.ne
                
    def insert(self,newElement):
        nod=self.head.ne
        while nod is not self.head:
            if nod.element==newElement:
                print('key',nod.element,'already exists')
                return 
            nod=nod.ne
            
        new=Node(newElement,None,None)
        x=self.head.pr
        x.ne=new
        new.pr=x
        self.head.pr=new
        new.ne=self.head   
                
            
            
a=[20,30,40,50,60,70]
b=DoublyList(a)
b.insert(50)
b.showList()
# Out:
# key 50 already exists
# 20
# 30
# 40
# 50
# 60
# 70

# %%
#TASK 2->4

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print(nod.element)
                nod=nod.ne
                
                
    def insert(self,newElement,index):
        if self.head.ne==None:
            print('Empty list')
            return
        else:
            count=0
            w=self.head.ne
            while w is not self.head:
                count+=1
                w=w.ne
            if index<0 or index>count:
                print('invalid index')
            else:
                nod=self.head.ne
                while nod is not self.head:
                    if nod.element==newElement:
                        print('key',nod.element,'already exists')
                        return 
                    nod=nod.ne
                    
                new1=Node(newElement,None,None)
                c=0
                d=self.head.ne
                while d is not self.head:
                    if c==index:
                        s1=d.pr
                        d.pr=new1
                        s1.ne=new1
                        new1.pr=s1
                        new1.ne=d
                    c+=1
                    d=d.ne
        

a=[20,30,40,50,60,70]
b=DoublyList(a)
b.insert(90,2)
b.showList()
# Out:
# 20
# 30
# 90
# 40
# 50
# 60
# 70

# %%
#TASK 2->5

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print(nod.element)
                nod=nod.ne
                
                
    def remove(self,index):
        if self.head.ne==None:
            print('Empty list')
            return
        else:
            count=0
            w=self.head.ne
            while w is not self.head:
                count+=1
                w=w.ne
            if index<0 or index>count:
                print('invalid index')
            
            c=0
            d=self.head.ne
            while d is not self.head:
                if c==index:
                    d.pr.ne=d.ne
                    d.ne.pr=d.pr
                    
                c+=1
                d=d.ne
            
        
            
a=[20,30,40,50,60,70]
b=DoublyList(a)
b.remove(3)
b.showList()
# Out:
# 20
# 30
# 40
# 60
# 70

# %%
#TASK 2->6

class Node:
    def __init__(self,element,n_node,pr_node):
        self.element=element
        self.ne=n_node
        self.pr=pr_node
        
class DoublyList:
    def __init__(self,a):
        if len(a)!=0:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
        
            for i in a:
                nod=Node(i,None,None)
                nod.ne=n.ne
                n.ne=nod
                nod.pr=n
                nod.ne.pr=nod
                n=nod
        
        else:
            self.head=Node(None,None,None)
            self.head.ne=self.head.pr=self.head
            n=self.head
            print('Empty list')
                
    def showList(self):
        s=self.head
        nod=self.head.ne
        if nod is None:
            print('Empty list')
        
        else:
            while nod is not s:
                print('list after deleting',nod.element)
                nod=nod.ne
                
                
    def removeKey(self,deleteKey):
        if self.head.ne==None:
            print('Empty list')
            return
        else:
            d=self.head.ne
            while d is not self.head:
                if d.element==deleteKey:
                    de=d
                    d.pr.ne=d.ne
                    d.ne.pr=d.pr
                d=d.ne
            return de.element
            
        
            
a=[20,30,40,50,60,70]
b=DoublyList(a)
print(b.removeKey(40))
b.showList()
# Out:
# 40
# list after deleting 20
# list after deleting 30
# list after deleting 50
# list after deleting 60
# list after deleting 70
