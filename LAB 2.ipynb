# %%
# TASK 2->(1(a))

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        while nod is not None: 
            print(nod.element,end='->')
            nod=nod.next_node
        print('\b'*2)
    
        
                 
a=[1,2,3,4,5]
li=MyList(a)
li.showList()
# Out:
# 1->2->3->4->5->

# %%
# TASK 2-> (2) 

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
        
                
a=[1,2,3,4,5]
li=MyList(a)
li.showList()
# Out:
# 1->2->3->4->5->

# %%
# 3

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def isEmpty(self):
        nod=self.head
        if nod is None:
            return 'true'
        else:
            return 'false'
        
                
a=[1,2,3,4,5]
li=MyList(a)
print(li.isEmpty())
# Out:
# false

# %%
# 4

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
                
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
    
                
    def clear(self):
        nod=self.head
        while nod is not None:
            nod.next_node=None
            nod=None
        self.head=None
        
a=[1,2,3,4,5]
li=MyList(a)
li.clear()
li.showList()
# Out:
# Empty list

# %%
# 5

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)

            
    
    def insert(self,newElement):
        nod=self.head
        y=0
        while nod.next_node!=None:
            if nod.element==newElement.element:
                y=1
                print('key',nod.element,'already exists')
            nod=nod.next_node
        if y==0:
            nod.next_node=newElement
            
    

a=[10,23,15,67,88,56,34,53]
b_li=MyList(a)
new_element=Node(56,None)
b_li.insert(new_element)
b_li.showList()
# Out:
# key 56 already exists
# 10->23->15->67->88->56->34->53->

# %%
# 6

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        for j in range(len(a)):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
            
    
    def insert(self,newElement,index):
        if self.head==None:
            print('Empty list')
        else:
            c=0
            nod=self.head
            while nod.next_node is not None:
                c+=1
                nod=nod.next_node
                
            if index<0 or index>c:
                print('invalid part')
            else:
                if index==0:
                    nod.next_node=newElement.element
                    newElement.element=self.head
                else:
                    for i in range(len(a)):
                        nod.next_node=newElement.element
                    
            nod=nod.next_node
    

a=[10,23,15,67,88,56,34,53]
b_li=MyList(a)
new_element=Node(40,None)
b_li.insert(new_element,2)
b_li.showList()
# Out:
# 10->23->15->67->88->56->34->53->
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-1603841d46fa> in <module>
#      60 new_element=Node(40,None)
#      61 b_li.insert(new_element,2)
# ---> 62 b_li.showList()
#
# <ipython-input-54-1603841d46fa> in showList(self)
#      28         else:
#      29             while nod is not None:
# ---> 30                 print(nod.element,end='->')
#      31                 nod=nod.next_node
#      32             print('\b'*2)
#
# AttributeError: 'int' object has no attribute 'element'

# %%
# 7

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)

    def remove(self,deleteKey):
        if self.head is None:
            print('Empty list')
        else:
            nod=self.head
            while nod is not None:
                if nod.element==deleteKey:
                    nod.next_node=None
                
                nod=nod.next_node
            
a=[10,23,15,67,88,56,34,53]
b_li=MyList(a)
b_li.remove(34)
b_li.showList()
# Out:
# 10->23->15->67->88->56->34->

# %%
# 3.1

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
        
    def evenList(self):
        nod=self.head
        x=Node(None,None)
        z=Node(None,None)
        for i in a:
            if nod.element%2==0:
                if x.element==None:
                    x=nod
                    z=x
                    
                else:
                    x.next_node=nod
                    x=x.next_node
        
            
            nod=nod.next_node
    
        while z is not None:
            print(z.element,end='->')
            z=z.next_node
        print('\b'*2)
    
            
a=[1,2,5,3,8]
b=MyList(a)
c=b.evenList()
# Out:
# 2->8->

# %%
# 3.2

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
                
    def find(self,ele):
        nod=self.head
        for i in a:
            if nod.element==ele:
                return 'True'
            nod=nod.next_node
        return 'False'
        
a=[1,2,5,3,8,7]
b=MyList(a)
f=b.find(5)
print(f)
# Out:
# True

# %%
# 3.3

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
                
                
    def reverse(self):
        n=None
        ne=n
        nod=self.head
        for w in a:
            if nod!=None:
                nex=nod.next_node
                nod.next_node=ne
                ne=nod
                nod=nex
            
        d=ne
        while d is not None:
            d=d.next_node
        self.head=ne
        
        
        
a=[1,2,5,3,8]
b=MyList(a)
b.reverse()
b.showList()
# Out:
# 8->3->5->2->1->

# %%
# 3.4

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)    
                
    def sort(self):
        if self.head==None:
            print('empty')
        else:
            count=0
            nod=self.head
            while nod.next_node!=None:
                count+=1
                nod=nod.next_node
            nod=self.head
            n1=nod.next_node
            i=0
            r=0
            while i<count:
                while r<count-i:
                    ne=nod.next_node
                    if nod.element>n1.element:
                        s=ne.element
                        ne.element=nod.element
                        nod.element=s
                    nod=nod.next_node
                i+=1
                r+=1
                f=self.head
                while f is not None:
                    print(f.element)
                    f=f.next_node
        
        
a=[1,2,5,3,8]
b=MyList(a)
b.sort()
b.showList()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-8c0a052ba05d> in <module>
#      65 a=[1,2,5,3,8]
#      66 b=MyList(a)
# ---> 67 b.sort()
#      68 b.showList()
#
# <ipython-input-63-8c0a052ba05d> in sort(self)
#      51                     ne=nod.next_node
#      52                     if nod.element>n1.element:
# ---> 53                         s=ne.element
#      54                         ne.element=nod.element
#      55                         nod.element=s
#
# AttributeError: 'NoneType' object has no attribute 'element'

# %%
# 3.5

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element,end='->')
                nod=nod.next_node
            print('\b'*2)
                
    def sum(self):
        sum1=0
        nod=self.head
        while nod is not None:
            sum1+=nod.element
            nod=nod.next_node
        print(sum1)
            
            
        
a=[1,2,5,3,8]
b=MyList(a)
t=b.sum()
# Out:
# 19

# %%
# 3.6

class Node:
    def __init__(self,element,next_node):
        self.element=element
        self.next_node=next_node
        
    

class MyList:
    def __init__(self,a):
        self.head=None
        t=None
        
        j=0
        while j<len(a):
            nod=Node(a[j],None)
            if self.head==None:
                self.head=nod
                t=nod
            else:
                t.next_node=nod
                t=nod
            j+=1
                
    def showList(self):
        nod=self.head
        if nod is None:
            print('Empty list')
        else:
            while nod is not None:
                print(nod.element)
                nod=nod.next_node
                
    def rotateLeft(self,k,direction):
        nod=self.head
        while nod is not None:
            nod.next_node=u
            m=nod.next_node
        for i in a:
            if u!=None:
                u=nod
        u=u.next_node
    
    def rotateRight(self,k,direction):
        nod=self.head
        while nod is not None:
            nod.next_node=u
            m=nod.next_node
        for i in a:
            if u!=None:
                u=nod
        u=u.next_node
        
        
a=[3,2,5,1,8]
b=MyList(a)
b.rotateLeft(2,'left')
b.showList()
b.rotateRight(3,'Right')
b.showList()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-61-ad0f71a99d27> in <module>
#      56 a=[3,2,5,1,8]
#      57 b=MyList(a)
# ---> 58 b.rotateLeft(2,'left')
#      59 b.showList()
#      60 b.rotateRight(3,'Right')
#
# <ipython-input-61-ad0f71a99d27> in rotateLeft(self, k, direction)
#      36         nod=self.head
#      37         while nod is not None:
# ---> 38             nod.next_node=u
#      39             m=nod.next_node
#      40         for i in a:
#
# UnboundLocalError: local variable 'u' referenced before assignment
