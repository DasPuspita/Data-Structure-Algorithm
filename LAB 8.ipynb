# %%
#TASK 1

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def height(self,root):
        if root.lef is None:
            if root.ri is not None:
                return 1+self.height(root.ri)
            else:
                return 1
            
        if root.ri is None:
            if root.lef is not None:
                return 1+self.height(root.lef)
            else:
                return 1
    
        else:
            return 1+max(self.height(root.lef),self.height(root.ri))
        
a=bi_tree()
print(a.height(a.root))
# Out:
# 3

# %%
#TASK 2

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def level(self,re):
        if re.parent is None:
            return 0
        else:
            c=self.level(re.parent)
            return 1+c
        
a=bi_tree()
print(a.level(a.root.lef.ri))
# Out:
# 2

# %%
#TASK 3

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def pre_orderTraversal(self,re):
        if re is not None:
            print(re.ele)
            self.pre_orderTraversal(re.lef)
            self.pre_orderTraversal(re.ri)

a=bi_tree()
a.pre_orderTraversal(a.root)
# Out:
# 33
# 4
# 66
# 5
# 8
# 79

# %%
#TASK 4

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def in_orderTraversal(self,re):
        if re is not None:
            self.in_orderTraversal(re.lef)
            print(re.ele)
            self.in_orderTraversal(re.ri)

a=bi_tree()
a.in_orderTraversal(a.root)
# Out:
# 66
# 4
# 5
# 33
# 79
# 8

# %%
#TASK 5

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def post_orderTraversal(self,re):
        if re is not None:
            self.post_orderTraversal(re.lef)
            self.post_orderTraversal(re.ri)
            print(re.ele)

a=bi_tree()
a.post_orderTraversal(a.root)
# Out:
# 66
# 5
# 4
# 79
# 8
# 33

# %%
#TASK 6

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        

        self.root2=Node(33,None,None,None)
        self.va7=Node(4,None,None,None)
        self.va8=Node(8,None,None,None)
        self.va9=Node(66,None,None,None)
        self.va10=Node(5,None,None,None)
        self.va11=Node(79,None,None,None)
        self.root2.lef=self.va7
        self.va7.parent=self.root2
        self.root2.ri=self.va8
        self.va8.parent=self.root2
        self.va7.lef=self.va9
        self.va9.parent=self.va7
        self.va7.ri=self.va10
        self.va10.parent=self.va7
        self.va8.lef=self.va11
        self.va11.parent=self.va8
        
    def equality(self,root,root2):
        if root is not None and root2 is not None:
            if root.ele is root2.ele:
                return self.equality(root.lef,root2.lef)
                return self.equality(root.ri,root2.ri)
        elif root is None and root2 is None:
            return 'Same'
        else:
            return 'Not Same'
                 
        
a=bi_tree()
print(a.equality(a.root,a.root2))
# Out:
# Same

# %%
#TASK 7

class Node:
    def __init__(self,ele,lef,ri,parent):
        self.ele=ele
        self.lef=lef
        self.ri=ri
        self.parent=parent
        
class bi_tree:
    def __init__(self):
        self.root=Node(33,None,None,None)
        self.va2=Node(4,None,None,None)
        self.va3=Node(8,None,None,None)
        self.va4=Node(66,None,None,None)
        self.va5=Node(5,None,None,None)
        self.va6=Node(79,None,None,None)
        self.root.lef=self.va2
        self.va2.parent=self.root
        self.root.ri=self.va3
        self.va3.parent=self.root
        self.va2.lef=self.va4
        self.va4.parent=self.va2
        self.va2.ri=self.va5
        self.va5.parent=self.va2
        self.va3.lef=self.va6
        self.va6.parent=self.va3
        
    def copy(self,root,ne=None):
        
        if root!=None:
            ne.root=self.copy(root.ele)
        
        elif root.lef==None:
            ne.root.lef=None
        elif root.lef!=None:
            ne.root.lef=self.copy(root.lef.ele)
        
        elif root.ri==None:
            ne.root.ri=None
        elif root.ri!=None:
            ne.root.ri=self.copy(root.ri.ele)   
            
        return ne.ele
        
a=bi_tree()
print(a.copy(a.root))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-2f13ae6b5807> in <module>
#      45
#      46 a=bi_tree()
# ---> 47 print(a.copy(a.root))
#
# <ipython-input-31-2f13ae6b5807> in copy(self, root, ne)
#      30
#      31         if root is not None:
# ---> 32             ne.root=self.copy(root.ele)
#      33
#      34         elif root.lef is None:
#
# <ipython-input-31-2f13ae6b5807> in copy(self, root, ne)
#      30
#      31         if root is not None:
# ---> 32             ne.root=self.copy(root.ele)
#      33
#      34         elif root.lef is None:
#
# AttributeError: 'int' object has no attribute 'ele'
